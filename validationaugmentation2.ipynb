# %%
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from imutils import paths
import os
from keras_preprocessing import image
from shutil import copyfile
import tensorflow 

datagen = ImageDataGenerator(
    
#     adaptive_equalization=True, 
#         histogram_equalization=True,
        rotation_range=90,
#         brightness_range=[0.2,1],
        width_shift_range=0.1,
        height_shift_range=0.1,
        
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest'
    
          )
# Out:
# Using TensorFlow backend.
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
imagePaths = list(paths.list_images("./binaug_cervic_validation2/original/abnormal_old"))
# print(imagePaths)

# imagePaths1 = list(paths.list_images("./binaug_cervic_train/binary/abnormal_old"))


savefilepath='./binaug_cervic_validation2/original/abnormal/'

savefilepath1='./binaug_cervic_validation2/binary/abnormal/'

SEED=100
filepath='./binaug_cervic_validation2/binary/abnormal_old/'
for (i, imagePath) in enumerate(imagePaths):
# extract the person name from the image path
#print("[INFO] processing image {}/{}".format(i + 1,len(imagePaths)))
#     dir1 = imagePath.split(os.path.sep)[-2]
#     print(imagePath)
    name = (imagePath.split(os.path.sep)[-1]).replace('.BMP','')
    name1 = (imagePath.split(os.path.sep)[-1]).replace('.BMP','-d.bmp')
#     path=filepath
#     print(path)
    filename=filepath+name1
    print(filename)
#     if not os.path.exists(filepath):
#         os.makedirs(filepath)
#     copyfile(imagePath, filename)
    img = load_img(imagePath)
    maskimg=load_img(filename)

    x = img_to_array(img)  # creating a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)  # converting to a Numpy array with shape (1, 3, 150, 150)
#     savefilename=savefilepath+name
    x1 = img_to_array(maskimg)  # creating a Numpy array with shape (3, 150, 150)
    x1 = x1.reshape((1,) + x1.shape)  
    ii = 0

#     ia.seed(4)

#     rotate = iaa.Affine(rotate=(-20, 90))
#     image_aug = rotate.augment_image(x)
    for (batch, batch1) in zip(datagen.flow(x, save_to_dir=savefilepath, save_prefix=name, save_format='BMP',seed=SEED), datagen.flow(x1, save_to_dir=savefilepath1, save_prefix=name, save_format='bmp',seed=SEED)):
        ii += 1
        if ii >10:
            break
#     print("Augmented:")
#     ia.imshow(image_aug)
# Out:
# ./binaug_cervic_validation2/binary/abnormal_old/149316117-149316122-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153655593-153655608-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149316941-149316961-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153826963-153826976-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149357849-149357857-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153275893-153275939-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153827595-153827604-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149316941-149316952-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153354858-153354901-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153826963-153826982-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153656862-153656891-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153314759-153314767-003-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149358108-149358125-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153827595-153827618-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149315671-149315740-003-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149315775-149315790-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153276386-153276405-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149316117-149316131-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149315671-149315740-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149316117-149316131-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153827595-153827611-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153657257-153657289-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153314857-153314882-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153314466-153314473-003-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149315775-149315790-003-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149316754-149316779-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149316754-149316779-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153354589-153354597-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153826963-153826982-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149315671-149315749-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153826963-153826970-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149357849-149357867-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153276386-153276405-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153826963-153826989-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149316025-149316032-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149357849-149357857-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153656957-153656964-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149316754-149316762-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153827595-153827611-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153314759-153314767-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149315671-149315740-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149316117-149316122-004-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149315671-149315740-004-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153827595-153827604-004-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153826963-153826982-003-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153827595-153827618-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153828877-153828890-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153657327-153657363-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153354858-153354901-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153828877-153828897-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149316117-149316122-003-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153828877-153828890-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153827595-153827604-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149357849-149357857-003-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153657257-153657289-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153826963-153826989-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149315775-149315790-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153314857-153314882-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153826963-153826976-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153275893-153275939-003-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149357849-149357867-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153655593-153655600-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153826963-153826976-003-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153655593-153655600-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153354589-153354597-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153314466-153314473-002-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/153656862-153656873-001-d.bmp
# ./binaug_cervic_validation2/binary/abnormal_old/149315671-149315749-002-d.bmp

# %%
import os

imagePaths1 = list(paths.list_images("./binaug_cervic_validation2/binary/abnormal_old"))
savefilepath1='./binaug_cervic_validation2/binary/abnormal/'

for (i, imagePath) in enumerate(imagePaths1):
    name = (imagePath.split(os.path.sep)[-1]).replace('-d.bmp','.bmp')
    filename=savefilepath1+name
    copyfile(imagePath, filename)

# %%
import os

imagePaths = list(paths.list_images("./binaug_cervic_validation2/original/abnormal_old"))

savefilepath='./binaug_cervic_validation2/original/abnormal/'


for (i, imagePath) in enumerate(imagePaths):
    name = (imagePath.split(os.path.sep)[-1])

    filename=savefilepath+name
    copyfile(imagePath, filename)

# %%
imagePaths = list(paths.list_images("./binaug_cervic_validation2/original/normal_old"))


savefilepath='./binaug_cervic_validation2/original/normal/'

savefilepath1='./binaug_cervic_validation2/binary/normal/'

SEED=100
filepath='./binaug_cervic_validation2/binary/normal_old/'
for (i, imagePath) in enumerate(imagePaths):
    name = (imagePath.split(os.path.sep)[-1]).replace('.BMP','')
    name1 = (imagePath.split(os.path.sep)[-1]).replace('.BMP','-d.bmp')
    filename=filepath+name1
#     print(filename)
    img = load_img(imagePath)
    maskimg=load_img(filename)

    x = img_to_array(img)  # creating a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)  # converting to a Numpy array with shape (1, 3, 150, 150)

    x1 = img_to_array(maskimg)  # creating a Numpy array with shape (3, 150, 150)
    x1 = x1.reshape((1,) + x1.shape)  
    ii = 0


    for (batch, batch1) in zip(datagen.flow(x, save_to_dir=savefilepath, save_prefix=name, save_format='BMP',seed=SEED), datagen.flow(x1, save_to_dir=savefilepath1, save_prefix=name, save_format='bmp',seed=SEED)):
        ii += 1
        if ii >10:
            break

# %%
import os

imagePaths1 = list(paths.list_images("./binaug_cervic_validation2/binary/normal_old"))
savefilepath1='./binaug_cervic_validation2/binary/normal/'

for (i, imagePath) in enumerate(imagePaths1):
    name = (imagePath.split(os.path.sep)[-1]).replace('-d.bmp','.bmp')
    filename=savefilepath1+name
    copyfile(imagePath, filename)

# %%
import os

imagePaths = list(paths.list_images("./binaug_cervic_validation2/original/normal_old"))

savefilepath='./binaug_cervic_validation2/original/normal/'


for (i, imagePath) in enumerate(imagePaths):
    name = (imagePath.split(os.path.sep)[-1])

    filename=savefilepath+name
    copyfile(imagePath, filename)
