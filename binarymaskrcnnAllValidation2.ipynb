# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
from PIL import Image # (pip install Pillow)


import os
from imutils import paths

# PATH="/content/drive/My Drive/dataset_binary/dataset_binary/"
basepath= './binaug_cervic_validation3/'
folderpath= basepath+'binary/'
folderpathorg = basepath+ 'original/'

# imagePaths = list(paths.list_images(folderpath))


class_names=[]
filenames1=[]
filenames=[]
mask_images=[]

for dirname in os.listdir(folderpath):
        class_names.append(dirname)
        print(dirname)
        path1=folderpath+dirname+'/'
        print(path1)
        for filename in os.listdir(path1):
            
            print(path1+filename)
            img= Image.open(path1+filename)
            mask_images.append(img)
            filenames1.append(dirname+'/'+filename)
            orgfilename=filename.replace('.bmp','.BMP')
            filenames.append(folderpathorg+dirname+'/'+orgfilename)
# Out:
# normal
# ./binaug_cervic_validation3/binary/normal/
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/209565698-209565729-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-003_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-002_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565503-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157224504-157224520-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522970-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209523052-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157227461-157227503-001.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268376-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/normal/157227058-157227087-001.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/209522940-209522991-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565600-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185814-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157224412-157224429-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/normal/157224172-157224207-003_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/157268342-157268401-001_0_973.bmp
# ./binaug_cervic_validation3/binary/normal/209565409-209565466-001.bmp
# ./binaug_cervic_validation3/binary/normal/157268242-157268296-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_298.bmp
# ./binaug_cervic_validation3/binary/normal/157185781-157185793-003_0_6598.bmp
# ./binaug_cervic_validation3/binary/normal/157267647-157267732-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/normal/157224458-157224483-001_0_6598.bmp
# abnormal
# ./binaug_cervic_validation3/binary/abnormal/
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656891-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316961-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656957-153656964-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-003_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-003_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828897-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-003_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316762-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-004_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316952-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-004_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-004_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656891-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828897-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-003_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655608-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-003_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/149358108-149358125-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-003_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316952-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149358108-149358125-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-003_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655608-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828897-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-003_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149358108-149358125-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828897-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-004_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-003_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-003_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316025-149316032-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826970-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-003_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656957-153656964-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316952-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316762-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-003_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-003_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656873-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-003_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316961-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656873-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826970-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-003.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-003.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828897-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316762-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-003_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-004_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656873-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656957-153656964-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826970-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-003_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316961-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656957-153656964-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316025-149316032-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-003_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-003_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826970-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-003_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-003_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316762-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-003_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316961-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-004_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316952-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655608-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-003_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316952-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655608-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657327-153657363-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-004_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-003_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656957-153656964-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-003_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657327-153657363-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828897-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826970-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316762-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-003_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656873-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-003_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656957-153656964-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-003_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657327-153657363-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-004_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-003.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-003_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656957-153656964-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-004.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655608-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-003_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828897-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-003_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316961-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-004_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-003_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826970-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316961-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-003_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149358108-149358125-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657327-153657363-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316961-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149358108-149358125-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002_0_973.bmp
# ...
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656873-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-004.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656891-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657327-153657363-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316025-149316032-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-003_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-004_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655608-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656957-153656964-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-004.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-003_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-003_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657327-153657363-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655608-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-003_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-004_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656957-153656964-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657327-153657363-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828897-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656891-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/149358108-149358125-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-003_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-003_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316762-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-003_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-003_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316952-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-003_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149358108-149358125-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657327-153657363-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-004_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826970-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-004_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-003_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316952-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-003_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656873-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316952-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-004_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153657257-153657289-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-003_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149358108-149358125-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-003_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-003_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826989-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153276386-153276405-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-003_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656957-153656964-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149358108-149358125-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-001_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655608-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-003_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149358108-149358125-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-002_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655608-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826970-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-003_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-003_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316952-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-004_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-004_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153656862-153656873-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-003.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-004_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-004_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-004_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314857-153314882-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827604-002_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-003_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-002_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315775-149315790-001_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-001_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827611-002_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826976-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-003_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-002_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314466-153314473-003_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/153655593-153655600-002_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316025-149316032-001_0_4661.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315749-002_0_3938.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-003_0_6914.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316025-149316032-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357867-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-001_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001_0_4149.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316762-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/149357849-149357857-001_0_973.bmp
# ./binaug_cervic_validation3/binary/abnormal/153275893-153275939-003_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316941-149316961-002_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153826963-153826982-002.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354858-153354901-001_0_6598.bmp
# ./binaug_cervic_validation3/binary/abnormal/153354589-153354597-001_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-004_0_3947.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316122-003_0_2093.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316754-149316779-001_0_4770.bmp
# ./binaug_cervic_validation3/binary/abnormal/149315671-149315740-004_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153827595-153827618-001.bmp
# ./binaug_cervic_validation3/binary/abnormal/153828877-153828890-001_0_298.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/149316117-149316131-002_0_2672.bmp
# ./binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_4770.bmp
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-d01b7df64f93> in <module>
#      26
#      27             print(path1+filename)
# ---> 28             img= Image.open(path1+filename)
#      29             mask_images.append(img)
#      30             filenames1.append(dirname+'/'+filename)
#
# ~/anaconda3/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#
# OSError: [Errno 24] Too many open files: './binaug_cervic_validation3/binary/abnormal/153314759-153314767-003_0_4770.bmp'

# %%
# !pip install Shapely

# %%
import numpy as np                                 # (pip install numpy)
from skimage import measure                        # (pip install scikit-image)
from shapely.geometry import Polygon, MultiPolygon # (pip install Shapely)

def create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd):
    # Find contours (boundary lines) around each sub-mask
    # Note: there could be multiple contours if the object
    # is partially occluded. (E.g. an elephant behind a tree)
    contours = measure.find_contours(sub_mask, 0.5, positive_orientation='low')

    segmentations = []
    polygons = []
    large=0
    for contour in contours:
        if large<len(contour):
            large=len(contour)

    print('large :'+ str(large))
    for contour in contours:
        if len(contour)==large :
            
            for i in range(len(contour)):
                row, col = contour[i]
                contour[i] = (col - 1, row - 1)

        
            poly = Polygon(contour)
            #print(poly)

            poly = poly.simplify(1.0, preserve_topology=False)
            polygons.append(poly)
    
            #segmentation = np.array(poly.interiors).ravel().tolist()

            segmentation = np.array(poly.exterior.coords).ravel().tolist()
            segmentations.append(segmentation)

        else:
            continue
    
    multi_poly = MultiPolygon(polygons)
  #     print(multi_poly)
    x, y, max_x, max_y = multi_poly.bounds
    width = max_x - x
    height = max_y - y
    bbox = (x, y, width, height)
    area = multi_poly.area
      
    annotation = {
                    
                                  
                                        'segmentation': segmentations,
                                        'area': area, 
                                        'iscrowd': is_crowd,
                                        'image_id':image_id,
                                        'bbox': bbox,
                                        'category_id':category_id, 
                                        'annotation_id': annotation_id
                                    
                  
                  }


    return annotation
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-1685cda6d725> in <module>
#       1 import numpy as np                                 # (pip install numpy)
# ----> 2 from skimage import measure                        # (pip install scikit-image)
#       3 from shapely.geometry import Polygon, MultiPolygon # (pip install Shapely)
#       4
#       5 def create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd):
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap_external.py in get_data(self, path)
#
# OSError: [Errno 24] Too many open files: '/home/thamizharasi/anaconda3/lib/python3.7/site-packages/skimage/__init__.py'
# Exception in thread IPythonHistorySavingThread:
# Traceback (most recent call last):
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/IPython/core/history.py", line 834, in run
#   File "</home/thamizharasi/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-23>", line 2, in writeout_cache
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/IPython/core/history.py", line 58, in needs_sqlite
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/IPython/core/history.py", line 780, in writeout_cache
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/IPython/core/history.py", line 764, in _writeout_input_cache
# sqlite3.OperationalError: unable to open database file
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py", line 97, in _event_pipe
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/thamizharasi/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#   File "</home/thamizharasi/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-24>", line 2, in run
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/IPython/core/history.py", line 58, in needs_sqlite
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/IPython/core/history.py", line 837, in run
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py", line 402, in write
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py", line 205, in schedule
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py", line 101, in _event_pipe
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/zmq/sugar/context.py", line 204, in socket
#   File "/home/thamizharasi/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py", line 59, in __init__
#   File "zmq/backend/cython/socket.pyx", line 328, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Unhandled exception in thread started by <bound method Thread._bootstrap of <HistorySavingThread(IPythonHistorySavingThread, started 140314299856640)>>

# %%
def create_sub_masks(mask_image):
    width, height = mask_image.size
    #print(mask_image.size)
    #print(width)
    #print(height)
    # Initialize a dictionary of sub-masks indexed by RGB colors
    sub_masks = {}
    for x in range(width):
        for y in range(height):
            # Get the RGB values of the pixel
            #pixel = mask_image.getpixel((x,y))[:3]
            pixel = mask_image.getpixel((x,y))
            #print(pixel)
            # If the pixel is not black...
            if pixel != (0):
                # Check to see if we've created a sub-mask...
                pixel_str = str(pixel)
                sub_mask = sub_masks.get(pixel_str)
                if sub_mask is None:
                   # Create a sub-mask (one bit per pixel) and add to the dictionary
                    # Note: we add 1 pixel of padding in each direction
                    # because the contours module doesn't handle cases
                    # where pixels bleed to the edge of the image
                    sub_masks[pixel_str] = Image.new('1', (width+2, height+2))

                # Set the pixel value to 1 (default is 0), accounting for padding
                sub_masks[pixel_str].putpixel((x+1, y+1), 1)

    return sub_masks, width, height

# %%
def create_image(mask_image, filename1,width1, height1, image_id):
    image_det=                  {
                                     'licence':0,
                                     'filename':filename1 , 
                                     'width':width1 , 
                                     'height':height1,
                                     'id':image_id 
                                }       
                
    return image_det

# %%
print(class_names)    

print(filenames)

# %%
# print(len(filenames1))

# %%
def category_find(class_name):

        switcher =    {
                        'normal': 1,
                        'abnormal': 2
                                     }
        return switcher.get(class_name)

# %%
imgannotations = []
fileid=0



categ=[]
# Create the annotations
annotations = []
annotation_id = 1
image_id = 1
is_crowd = 0
fileid=0

     
for (mask_image, classname) in zip(mask_images, filenames1):
    #print('loop')
    classname1= classname.split('/')[0]
    print(classname.split('/')[0])
    print('image_id :'+ str(image_id))
    category_id1= category_find(classname1)
    category={'supercategory':'cervic', 'category_id': category_id1, 'name': classname.split('/')[0]}
    categ.append(category)
#     imglist=[9,43,55,60,76,77,80,88]
         
    imglist=[]
    if image_id not in imglist :
        
        sub_masks, width, height = create_sub_masks(mask_image)
        for color, sub_mask in sub_masks.items():
            #category_id = category_ids[image_id][color]
            
            #category_id.append(cat_id)
            annot= create_image(sub_mask, filenames[fileid],width, height, image_id)
            imgannotations.append(annot)
            #width, height = mask_image.size
            print(filenames[fileid])
            annotation = create_sub_mask_annotation(sub_mask, image_id, category_id1, annotation_id, is_crowd )
            if annotation!=0:
              annotations.append(annotation)

            annotation_id = 1
   # elif image_id==16:
   #     continue
    image_id += 1
    fileid +=1
#print(json.dumps(annotations))

import json


# category_id = 2
# class_name= 'light_dysplastic'
image_info = {

                    'info': 
                              {
                                    "description": "cervic class 7 Dataset",
                                    "url": "http://cocodataset.org",
                                    "version": "1.0",
                                    "year": 2019,
                                    "contributor": "Trois Infotech",
                                    "date_created": "2019/12/30"
                               },
                    'licenses':  
                                 {
                                    "url": "http://creativecommons.org/licenses/by-nc-sa/2.0/",
                                    "id": 0,
                                    "name": "Attribution-NonCommercial-ShareAlike License"
                                 },
                    'categories':categ, 
                                
                    'images': imgannotations,
                    'annotations': annotations
                                  
}


with open('/content/drive/My Drive/binaug_cervic_validation3/cervic_binaryaug_class_validation2.json', 'w') as json_file:
 
        json.dump(image_info, json_file)
#         json.dump(annotations1, json_file)
#         json.dump(annotations, json_file)

# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# %%
# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = colors = ['blue','red','gold','green','purple',   'orange', 'salmon', 'pink', 
                                'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                               'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                               'magenta', 'sienna', 'maroon']
        
        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()
        
        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()
            
        
    def display_info(self):
        print('Dataset Info:')
        print('=============')
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))
        
        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

        
    def display_licenses(self):
        print('Licenses:')
        print('=========')
        
        requirements = [['id', int],
                        ['url', str],
                         ['name', str]]
        for license in self.licenses:
#             for key, item in license.items():
#                 print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(req, str(req_type)))
            print('')
        print('')
        
    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(cat_id, self.categories[cat_id]['name']))
            print('')
    
    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))
        
        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))
            
        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))
            
        else:
#             image_path = os.path.join(self.image_dir, image['filename'])
            image_path= image['filename']
            image = PILImage.open(image_path)
        
        # Calculate the size and adjusted display size
        max_width = 600
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height
        
        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        print('  segmentations ({}):'.format(len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height) * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append({'x': x_start, 'y': y_start, 'width': 1 , 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append({'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})
                            
                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1 # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(full_lines_to_insert * adjusted_ratio)
                                rle_list.append({'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})
                                
                            # Insert bottom line
                            rle_list.append({'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list  
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['image_id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['image_id']] = self.colors[i]
            else:
                poly_colors[segm['image_id']] = 'white'
            
            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] + bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['image_id']] = str(bbox_points).lstrip('[').rstrip(']')
            
            # Print details
            print('    {}:{}:{}'.format(segm['image_id'], poly_colors[segm['image_id']], self.categories[segm['category_id']]))
        
        
        
        # Draw segmentation polygons on image
        html  = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(adjusted_width, adjusted_height)
        
        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(points, fill_color, stroke_color)
        
        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(x, y, w, h, fill_color, stroke_color)
            
        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(points, fill_color, stroke_color)
                
        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html
       
    def process_info(self):
        self.info = self.coco['info']
    
    def process_licenses(self):
        self.licenses = self.coco['licenses']
    
    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['category_id']
            #cat_id = 1
            super_category = category['supercategory']
            #super_category = 1
            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                self.super_categories[super_category] = {cat_id} # Create a new set with the category id
            else:
                self.super_categories[super_category] |= {cat_id} # Add category id to the set
                
    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image
                
    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = '/content/drive/My Drive/binaug_cervic_validation3/cervic_binaryaug_class_validation2.json'
image_dir = '/content/drive/My Drive/binaug_cervic_validation3/original/abnormal'

coco_dataset = CocoDataset(annotation_path, image_dir)
# coco_dataset.display_info()
# coco_dataset.display_licenses()
coco_dataset.display_categories()

# %%
html = coco_dataset.display_image(101, use_url=False)
IPython.display.HTML(html)

# %%
file1= '/content/drive/My Drive/binaug_cervic_validation3/original/abnormal/149315775-149315790-001.BMP'
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread(file1)
cv2_imshow(img)

# %%
file1= '/content/drive/My Drive/binaug_cervic_validation3/binary/abnormal/149315775-149315790-001.bmp'
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread(file1)
cv2_imshow(img)

# %%
html = coco_dataset.display_image(1100, use_url=False)
IPython.display.HTML(html)

# %%
annotation_path='/content/drive/My Drive/binaug_cervic_validation3/cervic_binaryaug_class_validation2.json'
with open(annotation_path) as json_file:
    lines = json_file.readlines()
for line in lines:
    print(line)
