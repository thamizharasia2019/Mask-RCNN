# %%
import numpy as np                                 # (pip install numpy)
from skimage import measure                        # (pip install scikit-image)
from shapely.geometry import Polygon, MultiPolygon # (pip install Shapely)

def create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd):
    # Find contours (boundary lines) around each sub-mask
    # Note: there could be multiple contours if the object
    # is partially occluded. (E.g. an elephant behind a tree)
    contours = measure.find_contours(sub_mask, 0.5, positive_orientation='low')

    segmentations = []
    polygons = []
    large=0
    for contour in contours:
        if large<len(contour):
            large=len(contour)
    print(large)
    for contour in contours:
        if len(contour)==large:
            
            for i in range(len(contour)):
                row, col = contour[i]
                contour[i] = (col - 1, row - 1)

        
            poly = Polygon(contour)
            #print(poly)

            poly = poly.simplify(1.0, preserve_topology=False)
            polygons.append(poly)
    
            #segmentation = np.array(poly.interiors).ravel().tolist()
    
            segmentation = np.array(poly.exterior.coords).ravel().tolist()
            segmentations.append(segmentation)
        else:
            continue
    multi_poly = MultiPolygon(polygons)
#     print(multi_poly)
    x, y, max_x, max_y = multi_poly.bounds
    width = max_x - x
    height = max_y - y
    bbox = (x, y, width, height)
    area = multi_poly.area
    
    annotation = {
                   
                                
                                      'segmentation': segmentations,
                                      'area': area, 
                                      'iscrowd': is_crowd,
                                      'image_id':image_id,
                                      'bbox': bbox,
                                      'category_id':category_id, 
                                      'annotation_id': annotation_id
                                  
                
                }

    return annotation

# %%
from PIL import Image # (pip install Pillow)

def create_sub_masks(mask_image):
    width, height = mask_image.size
    #print(mask_image.size)
    #print(width)
    #print(height)
    # Initialize a dictionary of sub-masks indexed by RGB colors
    sub_masks = {}
    for x in range(width):
        for y in range(height):
            # Get the RGB values of the pixel
            #pixel = mask_image.getpixel((x,y))[:3]
            pixel = mask_image.getpixel((x,y))
            #print(pixel)
            # If the pixel is not black...
            if pixel != (0):
                # Check to see if we've created a sub-mask...
                pixel_str = str(pixel)
                sub_mask = sub_masks.get(pixel_str)
                if sub_mask is None:
                   # Create a sub-mask (one bit per pixel) and add to the dictionary
                    # Note: we add 1 pixel of padding in each direction
                    # because the contours module doesn't handle cases
                    # where pixels bleed to the edge of the image
                    sub_masks[pixel_str] = Image.new('1', (width+2, height+2))

                # Set the pixel value to 1 (default is 0), accounting for padding
                sub_masks[pixel_str].putpixel((x+1, y+1), 1)

    return sub_masks, width, height

# %%
def create_image(mask_image, filename1,width1, height1, image_id):
    image_det=                  {
                                     'licence':0,
                                     'filename':filename1 , 
                                     'width':width1 , 
                                     'height':height1,
                                     'id':image_id 
                                }       
                
    return image_det

# %%
import os
from imutils import paths

basepath='./binaug_cervic_train1/'
folderpath= basepath+'binary/'
folderpathorg = basepath+ 'original/'

# imagePaths = list(paths.list_images(folderpath))


class_names=[]
filenames1=[]
filenames=[]
mask_images=[]

for dirname in os.listdir(folderpath):
        class_names.append(dirname)
        print(dirname)
        path1=folderpath+dirname+'/'
        print(path1)
        for filename in os.listdir(path1):
            
            print(path1+filename)
            img= Image.open(path1+filename)
            mask_images.append(img)
#             filenames1.append(dirname+'/'+filename)
#             orgfilename=filename.replace('.bmp','.BMP')
#             filenames.append(folderpathorg+dirname+'/'+orgfilename)
# Out:
# normal
# ./binaug_cervic_train1/binary/normal/
# ./binaug_cervic_train1/binary/normal/157268504-157268534-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-003_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958364-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157222904-157223217-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-002_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184891-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-003_0_973.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307561-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224320-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183980-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157222904-157223196-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223349-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157183193-157183241-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157183193-157183241-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157184112-157184120-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/157185164-157185177-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181697-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-002_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157223321-157223328-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224320-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-002_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958621-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157222904-157223217-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184891-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183376-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-003_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-005_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181697-001.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-002_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184891-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-003_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-002_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-002_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958392-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-003_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/153956279-153956296-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-003_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157185133-157185143-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-004_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522522-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183840-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183376-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-004_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958621-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157181525-157181540-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-004_0_298.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-003_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-004_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-002_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-004_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157223659-157223667-002_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-002_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184023-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/209048086-209048239-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-001_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183877-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-002_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183614-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-003_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-004_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-002_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157185575-157185586-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/158989297-158989324-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-006_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-002_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-005_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-004_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157223659-157223667-002_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-002_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223766-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-002_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157181569-157181599-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-004_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-002_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-002_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-002_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-004_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-004_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-002_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157185054-157185079-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181686-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-006_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224320-002_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-009_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223751-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/209522316-209522391-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-006_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-002_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157223779-157224140-001.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-004_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157185309-157185360-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183991-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958248-002_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/153960256-153960295-002_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-004_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/157185309-157185360-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958211-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/209522316-209522391-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-004_0_973.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958248-003_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-007_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183991-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184976-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-002_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-009_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183346-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958392-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522522-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-002_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224336-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-004_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157222904-157223196-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181686-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/209522316-209522391-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-009_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522554-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/209522800-209522835-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-002_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-002_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157224244-157224258-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183980-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223364-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181708-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-002_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/209047881-209047928-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157185730-157185758-002_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/209522800-209522835-001.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-006_0_412.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958621-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157222904-157223196-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-008_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184023-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522554-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157185677-157185690-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/209522641-209522674-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-006_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-004_0_415.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522554-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-008_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-002_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-002_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157224458-157224464-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-006_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047626-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157224172-157224179-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222561-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-004_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157183193-157183279-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-004_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-004_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157223321-157223341-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222687-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183840-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-004_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-007_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222579-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/209522800-209522835-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157184112-157184128-001_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157223779-157224126-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157223779-157224140-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-004_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-003_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-007_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222561-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157185613-157185627-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/153955676-153955746-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522522-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-003_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-002_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183840-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-002_0_973.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-008_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-007_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-002_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-002_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-004_0_412.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/209522800-209522835-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184891-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-002_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157185730-157185758-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-002_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184870-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157183193-157183241-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157184112-157184120-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-005_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-002_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223766-001_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/153956279-153956296-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958621-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157184067-157184080-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185454-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958364-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-005_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-004_0_298.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307504-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-004_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-006_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-002_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958179-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-002_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157185208-157185238-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183840-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-002_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-004_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-002_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185454-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-005_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/153956279-153956296-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-001_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223766-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157185677-157185690-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-005_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184023-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183638-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522554-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-002.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183887-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-002_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/158989297-158989324-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-002_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223751-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157223659-157223667-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047626-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157184112-157184120-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157185677-157185690-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157224458-157224464-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223355-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183361-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-002_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223766-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958179-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157223779-157224126-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223364-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/153955676-153955746-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222687-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183361-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157185164-157185196-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224320-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307561-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183991-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222687-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-004_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157185164-157185196-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184891-001.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-006_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222687-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157223549-157223570-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-005_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958392-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-008_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157184112-157184120-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153955676-153955721-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184023-001.bmp
# ./binaug_cervic_train1/binary/normal/157223659-157223667-002_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181697-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/209048086-209048239-001_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157223321-157223328-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-003_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-003_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-004_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-001.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-006_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157223779-157224140-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-002_0_415.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-004_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222607-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-006_0_973.bmp
# ./binaug_cervic_train1/binary/normal/158989297-158989324-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157184112-157184120-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157268504-157268534-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958364-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157223246-157223258-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183614-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-009_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-006_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/209048086-209048239-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157185309-157185360-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-003_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157223246-157223258-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/209522641-209522674-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184039-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183638-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157183722-157183783-002_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-003_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047762-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184039-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222579-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157185309-157185360-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-005_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/209522641-209522674-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-002_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-003_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/158989297-158989324-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-002_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185454-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307561-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-003.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183840-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/209047881-209047928-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222660-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223349-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183887-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047626-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-002_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-002_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181686-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307561-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157183722-157183783-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/153955676-153955746-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047762-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-004_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223751-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157184999-157185032-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958179-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222579-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/209047881-209047928-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157223779-157224126-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157222801-157222811-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-003_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157222801-157222811-002_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-006_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-003_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183980-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222561-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-002_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181686-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157184112-157184120-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183614-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-005_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/153960256-153960295-002_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-003_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-002_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522522-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157183193-157183279-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222561-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/153955676-153955721-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157185164-157185177-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185454-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157183193-157183241-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-005_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-002_0_298.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-002_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222607-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183840-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-004_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157223246-157223258-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/158989297-158989324-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157223659-157223667-002_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-004_0_412.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-007_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-001_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157224172-157224179-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-005_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-003_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-003_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-002_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307504-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183614-001_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181697-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184023-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185454-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157181387-157181418-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157185730-157185758-002_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-004_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157223549-157223570-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958211-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157185730-157185758-002_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958392-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157184999-157185032-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184891-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/153956279-153956296-001.bmp
# ./binaug_cervic_train1/binary/normal/157224244-157224258-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223364-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-002_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958248-002_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222607-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222579-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-003_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157183193-157183279-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-002_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-003_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222660-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157222801-157222811-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-001.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-002_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157223321-157223328-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183656-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184976-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157181569-157181599-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157183193-157183241-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224336-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-002_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157185208-157185238-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-004_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958364-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157185575-157185586-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157224352-157224395-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-004_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183656-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157222904-157223196-001.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-002_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157184999-157185032-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/209047881-209047928-001.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-002_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-002_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-007_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-007_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223751-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157181281-157181308-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-006_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-004_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522554-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-006_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958211-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-002_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184039-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958248-002_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222579-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-009_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958364-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-002_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-007_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307561-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157223779-157224140-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307504-001.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181697-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222561-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-003_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-004_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184942-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157183722-157183783-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157224244-157224258-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958211-001.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-004_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157224458-157224464-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-003_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184942-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183840-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-004_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181697-001_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-002_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183361-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-002_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958248-003_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157185730-157185758-002_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183614-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185454-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958392-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222687-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307504-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222687-001.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047626-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/153956279-153956296-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-004_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223751-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223355-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184870-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157222904-157223196-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/209047881-209047928-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157181569-157181599-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157185730-157185758-001.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222607-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157222801-157222811-002_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184023-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183638-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-005_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958248-002_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-004_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224336-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522554-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183887-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-003_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-003_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-002_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183840-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-003_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184031-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157224172-157224179-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183887-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047626-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184891-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-003_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157224244-157224258-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183877-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958392-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-007_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183638-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-006_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183656-001_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-003_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-002_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157181525-157181540-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958179-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-002_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184870-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157185164-157185196-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157183722-157183783-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522522-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157223321-157223341-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522522-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522554-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157185613-157185627-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157181281-157181308-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-003_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-002_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157185164-157185177-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185454-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184870-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/209522316-209522391-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184942-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-003_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157185730-157185758-002_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153960256-153960295-002_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157222801-157222811-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-003_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-002_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181697-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157223779-157224126-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222660-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-002_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181686-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157222904-157223217-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-002_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222660-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157224172-157224179-001.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184976-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-005_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157184999-157185032-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157185677-157185690-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222687-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224336-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183877-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184870-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183346-001_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/157185054-157185079-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307504-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/209522316-209522391-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157222904-157223217-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157268504-157268534-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/209522800-209522835-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184023-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223766-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183656-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157185208-157185238-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/153956279-153956296-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958621-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-003_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157185730-157185758-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157181387-157181418-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-002_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-002_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/153955676-153955746-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181697-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/153955676-153955721-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223355-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/153955676-153955746-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157184067-157184080-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-003_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-002_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/209522474-209522522-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-002_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184031-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157181525-157181540-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-004_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-002_0_415.bmp
# ./binaug_cervic_train1/binary/normal/153955676-153955746-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-002_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183991-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184039-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958211-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-004_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-004_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157185164-157185196-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-002_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-002_0_973.bmp
# ...
# ./binaug_cervic_train1/binary/normal/157183332-157183346-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958364-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-002_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-003_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184976-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-002_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-003_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-003_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157224458-157224464-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157223321-157223328-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-004_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-002_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-002_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157223659-157223667-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223364-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/209522316-209522391-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/157181569-157181599-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223349-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047762-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183638-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-004_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-003_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-003_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222561-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157222801-157222811-002_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-004_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-002_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223406-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-004_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-007.bmp
# ./binaug_cervic_train1/binary/normal/157181281-157181308-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958179-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958248-002_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184942-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-007_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183346-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-002.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-004_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157222801-157222844-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223766-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157184999-157185032-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183887-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-004_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-004_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157223321-157223328-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157224458-157224464-001.bmp
# ./binaug_cervic_train1/binary/normal/157185309-157185360-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157223246-157223258-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157223549-157223570-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181686-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184023-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157222904-157223196-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-002_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222607-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157223779-157224140-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184031-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/209047881-209047928-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184942-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047762-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/209522316-209522391-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-004_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223349-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157185677-157185690-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183991-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157185677-157185690-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181708-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157185133-157185143-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307561-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157223321-157223328-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157185575-157185586-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-003_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-002_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-008_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157223659-157223667-001_0_415.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224320-002_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183991-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157223549-157223570-001_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223349-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-003_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-003_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-002_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157223735-157223751-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183656-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-002_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184920-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-005_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-006_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157184999-157185032-001_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956072-004_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157183722-157183783-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958179-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157183193-157183241-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/209307421-209307561-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224320-002_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/158989297-158989324-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157224172-157224179-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-003_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183877-001_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157222607-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183376-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-002_0_298.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958179-002_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958621-001_0_4811.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183361-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157181525-157181540-001.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-003_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-002_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157185208-157185238-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183376-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-004_0_2814.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-003_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157185133-157185143-001_0_973.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-002_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958168-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157223321-157223341-001_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-002_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-002_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157223659-157223667-002_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183656-001_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/157185677-157185690-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047626-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181686-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-002_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157181569-157181599-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-003.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-002_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-002_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-002_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157222534-157223355-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958248-003_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157184013-157184031-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-006_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958364-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958211-001_0_3947.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184942-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-002_0_3938.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-001_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184891-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157185527-157185540-003_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157223394-157223428-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-006_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-005_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183980-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/157181569-157181599-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/209048086-209048239-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/209522316-209522391-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157223321-157223328-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/153960256-153960295-002_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958590-002_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-003_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958364-001_0_2257.bmp
# ./binaug_cervic_train1/binary/normal/157183412-157183638-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183346-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-006_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157185613-157185627-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/157184067-157184080-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157184850-157184976-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181697-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157184112-157184120-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183361-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958179-002_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153958154-153958194-003_0_6703.bmp
# ./binaug_cervic_train1/binary/normal/153956279-153956296-001_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-002_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157185781-157185793-002_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-003_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157223246-157223258-001_0_6598.bmp
# ./binaug_cervic_train1/binary/normal/209048086-209048239-001.bmp
# ./binaug_cervic_train1/binary/normal/157223659-157223667-002_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157183193-157183241-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-001_0_5012.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-002.bmp
# ./binaug_cervic_train1/binary/normal/157223659-157223667-002_0_1342.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157183964-157183991-001_0_6935.bmp
# ./binaug_cervic_train1/binary/normal/157181671-157181708-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183877-001_0_6914.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183877-001_0_298.bmp
# ./binaug_cervic_train1/binary/normal/157223246-157223258-001_0_3894.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183388-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-003.bmp
# ./binaug_cervic_train1/binary/normal/157181481-157181497-004_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157181146-157181197-001_0_9672.bmp
# ./binaug_cervic_train1/binary/normal/157222737-157222750-002_0_4149.bmp
# ./binaug_cervic_train1/binary/normal/153958345-153958392-001_0_2856.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185479-001_0_8492.bmp
# ./binaug_cervic_train1/binary/normal/153956444-153956458-004_0_1323.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222660-001_0_4770.bmp
# ./binaug_cervic_train1/binary/normal/157223246-157223258-001_0_5067.bmp
# ./binaug_cervic_train1/binary/normal/209048086-209048239-001_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224304-001_0_4661.bmp
# ./binaug_cervic_train1/binary/normal/209047526-209047762-001_0_9486.bmp
# ./binaug_cervic_train1/binary/normal/157183332-157183361-001_0_5525.bmp
# ./binaug_cervic_train1/binary/normal/157185433-157185508-004_0_2234.bmp
# ./binaug_cervic_train1/binary/normal/153956040-153956058-003_0_6370.bmp
# ./binaug_cervic_train1/binary/normal/153958547-153958572-002_0_2672.bmp
# ./binaug_cervic_train1/binary/normal/157185133-157185143-001_0_412.bmp
# ./binaug_cervic_train1/binary/normal/157224297-157224320-001_0_2093.bmp
# ./binaug_cervic_train1/binary/normal/157183828-157183840-001_0_9785.bmp
# ./binaug_cervic_train1/binary/normal/157222647-157222660-001_0_6598.bmp
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-c27594b4171e> in <module>
#      22
#      23             print(path1+filename)
# ---> 24             img= Image.open(path1+filename)
#      25             mask_images.append(img)
#      26 #             filenames1.append(dirname+'/'+filename)
#
# ~/anaconda3/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#
# OSError: [Errno 24] Too many open files: './binaug_cervic_train1/binary/normal/157222647-157222660-001_0_6598.bmp'

# %%
print(class_names)    
print(filenames)  
print(filenames1)

# %%
def category_find(class_name):

        switcher =    {
                        'normal': 1,
                        'abnormal': 2
                                     }
        return switcher.get(class_name)

# %%
imgannotations = []
fileid=0



categ=[]
# Create the annotations
annotations = []
annotation_id = 1
image_id = 1
is_crowd = 0
fileid=0

     
for (mask_image, classname) in zip(mask_images, filenames1):
    #print('loop')
    classname1= classname.split('/')[0]
#     print(classname.split('/')[0])
    print(image_id)
    category_id1= category_find(classname1)
    category={'supercategory':'cervic', 'category_id': category_id1, 'name': classname.split('/')[0]}
    categ.append(category)
#     imglist=[12,22,25,30,55,69,101,121,134,144,147,152,162,174,175,176,200,206,213,227,228,
#             231,234,244,245,281,286,302,312,314,321,340,344,357,366,381,388,393,394,399,
#             400,401,415,425,459,465,484,492,494,495,504,516,531,535,559,565,567,571,586,
#             590,592,606,626,632]
         
    imglist=[]
    if image_id not in imglist :
        
        sub_masks, width, height = create_sub_masks(mask_image)
        for color, sub_mask in sub_masks.items():
            #category_id = category_ids[image_id][color]
            
            #category_id.append(cat_id)
            annot= create_image(sub_mask, filenames[fileid],width, height, image_id)
            imgannotations.append(annot)
            #width, height = mask_image.size
            annotation = create_sub_mask_annotation(sub_mask, image_id, category_id1, annotation_id, is_crowd )
            annotations.append(annotation)

            annotation_id = 1
   # elif image_id==16:
   #     continue
    image_id += 1
    fileid +=1
#print(json.dumps(annotations))

import json


# category_id = 2
# class_name= 'light_dysplastic'
image_info = {

                    'info': 
                              {
                                    "description": "cervic class 7 Dataset",
                                    "url": "http://cocodataset.org",
                                    "version": "1.0",
                                    "year": 2019,
                                    "contributor": "Trois Infotech",
                                    "date_created": "2020/01/03"
                               },
                    'licenses':  
                                 {
                                    "url": "http://creativecommons.org/licenses/by-nc-sa/2.0/",
                                    "id": 0,
                                    "name": "Attribution-NonCommercial-ShareAlike License"
                                 },
                    'categories':categ, 
                                
                    'images': imgannotations,
                    'annotations': annotations
                                  
}

with open('./binaug_cervic_train1/cervic_binaryaug_class_train1.json', 'w') as json_file:
 
        json.dump(image_info, json_file)
#         json.dump(annotations1, json_file)
#         json.dump(annotations, json_file)

# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# %%
# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = colors = ['blue','red','gold','green','purple',   'orange', 'salmon', 'pink', 
                                'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                               'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                               'magenta', 'sienna', 'maroon']
        
        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()
        
        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()
            
        
    def display_info(self):
        print('Dataset Info:')
        print('=============')
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))
        
        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

        
    def display_licenses(self):
        print('Licenses:')
        print('=========')
        
        requirements = [['id', int],
                        ['url', str],
                         ['name', str]]
        for license in self.licenses:
#             for key, item in license.items():
#                 print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(req, str(req_type)))
            print('')
        print('')
        
    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(cat_id, self.categories[cat_id]['name']))
            print('')
    
    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))
        
        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))
            
        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))
            
        else:
#             image_path = os.path.join(self.image_dir, image['filename'])
            image_path= image['filename']
            image = PILImage.open(image_path)
        
        # Calculate the size and adjusted display size
        max_width = 600
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height
        
        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        print('  segmentations ({}):'.format(len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height) * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append({'x': x_start, 'y': y_start, 'width': 1 , 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append({'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})
                            
                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1 # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(full_lines_to_insert * adjusted_ratio)
                                rle_list.append({'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})
                                
                            # Insert bottom line
                            rle_list.append({'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list  
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['image_id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['image_id']] = self.colors[i]
            else:
                poly_colors[segm['image_id']] = 'white'
            
            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] + bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['image_id']] = str(bbox_points).lstrip('[').rstrip(']')
            
            # Print details
            print('    {}:{}:{}'.format(segm['image_id'], poly_colors[segm['image_id']], self.categories[segm['category_id']]))
        
        
        
        # Draw segmentation polygons on image
        html  = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(adjusted_width, adjusted_height)
        
        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(points, fill_color, stroke_color)
        
        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(x, y, w, h, fill_color, stroke_color)
            
        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(points, fill_color, stroke_color)
                
        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html
       
    def process_info(self):
        self.info = self.coco['info']
    
    def process_licenses(self):
        self.licenses = self.coco['licenses']
    
    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['category_id']
            #cat_id = 1
            super_category = category['supercategory']
            #super_category = 1
            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                self.super_categories[super_category] = {cat_id} # Create a new set with the category id
            else:
                self.super_categories[super_category] |= {cat_id} # Add category id to the set
                
    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image
                
    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = './binaug_cervic_train1/cervic_binaryaug_class_train1.json'
image_dir = './bin_cervic_train/original/abnormal'

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
# coco_dataset.display_licenses()
coco_dataset.display_categories()

# %%
html = coco_dataset.display_image(25, use_url=False)
IPython.display.HTML(html)

# %%
html = coco_dataset.display_image(55, use_url=False)
IPython.display.HTML(html)

# %%
annotation_path='./binaug_cervic_train1/cervic_binaryaug_class_train1.json'
with open(annotation_path) as json_file:
    lines = json_file.readlines()
for line in lines:
    print(line)
