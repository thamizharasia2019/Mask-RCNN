# %%
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from imutils import paths
import os
from keras_preprocessing import image
from shutil import copyfile
import tensorflow 

datagen = ImageDataGenerator(
    
#     adaptive_equalization=True, 
#         histogram_equalization=True,
        rotation_range=90,
#         brightness_range=[0.2,1],
        width_shift_range=0.1,
        height_shift_range=0.1,
        
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest'
    
          )
# Out:
# Using TensorFlow backend.
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
imagePaths = list(paths.list_images("./binaug_cervic_train2/original/abnormal_old"))
# print(imagePaths)

# imagePaths1 = list(paths.list_images("./binaug_cervic_train/binary/abnormal_old"))


savefilepath='./binaug_cervic_train2/original/abnormal/'

savefilepath1='./binaug_cervic_train2/binary/abnormal/'

SEED=100
filepath='./binaug_cervic_train2/binary/abnormal_old/'
for (i, imagePath) in enumerate(imagePaths):
# extract the person name from the image path
#print("[INFO] processing image {}/{}".format(i + 1,len(imagePaths)))
#     dir1 = imagePath.split(os.path.sep)[-2]
#     print(imagePath)
    name = (imagePath.split(os.path.sep)[-1]).replace('.BMP','')
    name1 = (imagePath.split(os.path.sep)[-1]).replace('.BMP','-d.bmp')
#     path=filepath
#     print(path)
    filename=filepath+name1
    print(filename)
#     if not os.path.exists(filepath):
#         os.makedirs(filepath)
#     copyfile(imagePath, filename)
    img = load_img(imagePath)
    maskimg=load_img(filename)

    x = img_to_array(img)  # creating a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)  # converting to a Numpy array with shape (1, 3, 150, 150)
#     savefilename=savefilepath+name
    x1 = img_to_array(maskimg)  # creating a Numpy array with shape (3, 150, 150)
    x1 = x1.reshape((1,) + x1.shape)  
    ii = 0

#     ia.seed(4)

#     rotate = iaa.Affine(rotate=(-20, 90))
#     image_aug = rotate.augment_image(x)
    for (batch, batch1) in zip(datagen.flow(x, save_to_dir=savefilepath, save_prefix=name, save_format='BMP',seed=SEED), datagen.flow(x1, save_to_dir=savefilepath1, save_prefix=name, save_format='bmp',seed=SEED)):
        ii += 1
        if ii >10:
            break
#     print("Augmented:")
#     ia.imshow(image_aug)
# Out:
# ./binaug_cervic_train2/binary/abnormal_old/149140849-149140856-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149105131-149105155-004-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149097324-149097352-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153314956-153314985-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149100006-149100018-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149182550-149182571-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149182125-149182135-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153659229-153659264-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149056933-149056982-006-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153655016-153655039-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149315229-149315310-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149056321-149056343-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149148124-149148181-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149357849-149357874-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149315229-149315291-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148841826-148841854-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148503400-148503415-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149185604-149185629-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149056410-149056423-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149317002-149317010-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149315229-149315249-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149061666-149061699-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149187049-149187073-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149058881-149058910-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153654325-153654360-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149054642-149054677-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148503071-148503092-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149054642-149054677-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149058170-149058218-004-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149101620-149101650-004-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149056321-149056360-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149105131-149105205-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149317002-149317010-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148848523-148848559-004-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149146886-149146936-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149182657-149182713-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149014929-149015008-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149317204-149317230-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148883996-148884017-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149146837-149146854-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153659229-153659243-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153314857-153314909-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148886869-148886897-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149101620-149101650-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149014631-149014654-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149057756-149057788-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153659229-153659256-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149181904-149182044-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149182657-149182698-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153659229-153659256-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149096927-149096943-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149014929-149014984-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149788716-149788727-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153314466-153314473-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149143370-149143378-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149056321-149056343-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149062277-149062289-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149185698-149185721-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149056785-149056797-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149143295-149143307-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/
003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149182550-149182571-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148499815-148500094-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148495842-148495854-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153655016-153655039-004-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149182657-149182713-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149182657-149182667-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149014631-149014646-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149057756-149057766-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149102510-149102527-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149182657-149182698-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148497788-148497836-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149097324-149097388-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153657121-153657160-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149057812-149057825-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149185698-149185721-004-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149105289-149105300-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153654869-153654880-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148842055-148842064-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149058170-149058218-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148719308-148719348-005-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149058262-149058309-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149317002-149317010-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149182657-149182667-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149058262-149058288-004-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149015418-149015435-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148881870-148881960-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149187049-149187090-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149095913-149095926-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149061666-149061699-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149054277-149054304-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149185405-149185423-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149143370-149143388-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149105289-149105311-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149147949-149147960-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149057164-149057197-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149185604-149185645-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149053945-149053983-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153659229-153659256-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149185698-149185709-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149097594-149097637-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/148710162-148710195-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153314857-153314909-002-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149788716-149788727-003-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149054169-149054199-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149058262-149058288-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/149100064-149100072-001-d.bmp
# ./binaug_cervic_train2/binary/abnormal_old/153654325-153654351-002-d.bmp

# %%
import os

imagePaths1 = list(paths.list_images("./binaug_cervic_train2/binary/abnormal_old"))
savefilepath1='./binaug_cervic_train2/binary/abnormal/'

for (i, imagePath) in enumerate(imagePaths1):
    name = (imagePath.split(os.path.sep)[-1]).replace('-d.bmp','.bmp')
    filename=savefilepath1+name
    copyfile(imagePath, filename)

# %%
import os

imagePaths = list(paths.list_images("./binaug_cervic_train2/original/abnormal_old"))

savefilepath='./binaug_cervic_train2/original/abnormal/'


for (i, imagePath) in enumerate(imagePaths):
    name = (imagePath.split(os.path.sep)[-1])

    filename=savefilepath+name
    copyfile(imagePath, filename)

# %%
imagePaths = list(paths.list_images("./binaug_cervic_train2/original/normal_old"))


savefilepath='./binaug_cervic_train2/original/normal/'

savefilepath1='./binaug_cervic_train2/binary/normal/'

SEED=100
filepath='./binaug_cervic_train2/binary/normal_old/'
for (i, imagePath) in enumerate(imagePaths):
    name = (imagePath.split(os.path.sep)[-1]).replace('.BMP','')
    name1 = (imagePath.split(os.path.sep)[-1]).replace('.BMP','-d.bmp')
    filename=filepath+name1
#     print(filename)
    img = load_img(imagePath)
    maskimg=load_img(filename)

    x = img_to_array(img)  # creating a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)  # converting to a Numpy array with shape (1, 3, 150, 150)

    x1 = img_to_array(maskimg)  # creating a Numpy array with shape (3, 150, 150)
    x1 = x1.reshape((1,) + x1.shape)  
    ii = 0


    for (batch, batch1) in zip(datagen.flow(x, save_to_dir=savefilepath, save_prefix=name, save_format='BMP',seed=SEED), datagen.flow(x1, save_to_dir=savefilepath1, save_prefix=name, save_format='bmp',seed=SEED)):
        ii += 1
        if ii >10:
            break

# %%
import os

imagePaths1 = list(paths.list_images("./binaug_cervic_train2/binary/normal_old"))
savefilepath1='./binaug_cervic_train2/binary/normal/'

for (i, imagePath) in enumerate(imagePaths1):
    name = (imagePath.split(os.path.sep)[-1]).replace('-d.bmp','.bmp')
    filename=savefilepath1+name
    copyfile(imagePath, filename)

# %%
import os

imagePaths = list(paths.list_images("./binaug_cervic_train2/original/normal_old"))

savefilepath='./binaug_cervic_train2/original/normal/'


for (i, imagePath) in enumerate(imagePaths):
    name = (imagePath.split(os.path.sep)[-1])

    filename=savefilepath+name
    copyfile(imagePath, filename)
